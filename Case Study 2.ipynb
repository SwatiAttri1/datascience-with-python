# %% [markdown]
# Import both the data sets “Cust_data” & “Cust_Demo” into python and solve the below questions using functions from “pandas” module.

# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# u'C:\\Users\\hp\\Downloads\\python\\Pandas Case Study\\3. Pandas Case Study-1'

# %%
custdata=pd.read_csv("C:\Users\hp\Downloads\python\Pandas Case Study\cust_data.csv")
custdemo=pd.read_csv("C:\Users\hp\Downloads\python\Pandas Case Study\cust_demo.csv")

# %%
custdata.head()
# Out:
#    ID  SeriousDlqin2yrs  RevolvingUtilization  No_of_30_59_DPD  DebtRatio  \
# 0   1                 1              0.766127                2   0.403261
# 1   2                 0              0.957151                0   0.796738
# 2   3                 0              0.658180                1   0.154685
# 3   4                 0              0.233810                0   0.327127
# 4   5                 0              0.907239                1   0.001316
#
#    MonthlyIncome  No_Of_OpenCreditLines  No_of_90_DPD  No_of_RealEstateLoans  \
# 0           9120                     13             0                      6
# 1           2600                      4             0                      0
# 2           3042                      2             1                      0
# 3           3300                      5             0                      0
# 4          63588                      7             0                      1
#
#    No_of_60_89_DPD
# 0                0
# ...

# %%
custdemo.head()
# Out:
#        ID                  Location  Gender  age Martial_Status  \
# 0    4532       Gandhinagar,Gujarat       0   39         Single
# 1  148736  Hyderabad,Andhra Pradesh       0   52        Married
# 2   95965   Shimla,Himachal Pradesh       0   62        Married
# 3   61759               Srinagar,JK       0   42         Single
# 4   49806            Imphal,Manipur       0   41         Single
#
#    NumberOfDependents  Own_House  No_Years_address
# 0                 1.0          1                 3
# 1                 0.0          0                 3
# 2                 0.0          0                 2
# 3                 1.0          1                 1
# 4                 1.0          0                 3

# %% [markdown]
# Create sub set of cust_demo as “cust_s1” with ID, age, Gender and Location variables using the condition marital_status = “Married” and Own_house = 1 and age>28.

# %%
cust_s1=custdemo[['ID','age','Gender','Location']].where((custdemo.Martial_Status=='Married')  & (custdemo.age>28) & (custdemo.Own_House==1))

# %%
cust_s1=cust_s1.dropna()
cust_s1
# Out:
#               ID   age  Gender                    Location
# 28       26404.0  33.0     0.0         Kolkata,West Bengal
# 42      137858.0  34.0     0.0          Chennai,Tamil Nadu
# 50       57715.0  39.0     1.0   Thiruvananthapuram,Kerala
# 52       76230.0  53.0     1.0          Chandigarh,Haryana
# 56        8493.0  78.0     1.0            Ranchi,Jharkhand
# 65      110537.0  43.0     1.0        Dehradun,Uttarakhand
# 70      148374.0  60.0     1.0         Gandhinagar,Gujarat
# 71      114149.0  66.0     1.0                  Panjim,Goa
# 100      75180.0  68.0     0.0              Aizawl,Mizoram
# 106      29409.0  76.0     1.0       Bhopal,Madhya Pradesh
# 120     139384.0  56.0     0.0                 Patna,Bihar
# 130      80213.0  30.0     1.0          Shillong,Meghalaya
# 133     129906.0  37.0     0.0  Itanagar,Arunachal Pradesh
# 139      56350.0  58.0     0.0         Kolkata,West Bengal
# 152      13587.0  37.0     0.0             Kohima,Nagaland
# ...

# %% [markdown]
# Sort the cust_s1 dataset using location in ascending order and age in descending order with in the location.

# %%
cust_s1.sort_values(by=['Location', 'age'], ascending=[True,False])
# Out:
#               ID   age  Gender                   Location
# 83512   106073.0  90.0     1.0           Agartala,Tripura
# 49124     8967.0  88.0     1.0           Agartala,Tripura
# 65242    44249.0  87.0     1.0           Agartala,Tripura
# 148381   28287.0  86.0     0.0           Agartala,Tripura
# 64155    60165.0  85.0     0.0           Agartala,Tripura
# 147738   22031.0  85.0     1.0           Agartala,Tripura
# 90405    87535.0  84.0     0.0           Agartala,Tripura
# 105693   59383.0  84.0     1.0           Agartala,Tripura
# 109795    8645.0  84.0     1.0           Agartala,Tripura
# 149431   18627.0  84.0     0.0           Agartala,Tripura
# 43491    87397.0  82.0     0.0           Agartala,Tripura
# 55891    92549.0  82.0     1.0           Agartala,Tripura
# 33226   145495.0  81.0     1.0           Agartala,Tripura
# 43577   135697.0  81.0     1.0           Agartala,Tripura
# 11624    53725.0  79.0     0.0           Agartala,Tripura
# ...

# %% [markdown]
# Rename the variable “NumberOfDependents” as “No_of_dependents” in cust_demo data.

# %%
custdemo.rename(columns={'NumberOfDependents':'No_of_dependents'}).head()
# Out:
#        ID                  Location  Gender  age Martial_Status  \
# 0    4532       Gandhinagar,Gujarat       0   39         Single
# 1  148736  Hyderabad,Andhra Pradesh       0   52        Married
# 2   95965   Shimla,Himachal Pradesh       0   62        Married
# 3   61759               Srinagar,JK       0   42         Single
# 4   49806            Imphal,Manipur       0   41         Single
#
#    No_of_dependents  Own_House  No_Years_address
# 0               1.0          1                 3
# 1               0.0          0                 3
# 2               0.0          0                 2
# 3               1.0          1                 1
# 4               1.0          0                 3

# %% [markdown]
# Remove duplicates from the both data sets Cust_data & Cust_Demo.

# %%
custdata[custdata.duplicated()==False]
custdemo[custdemo.duplicated()==False]
# Out:
#             ID                    Location  Gender  age Martial_Status  \
# 0         4532         Gandhinagar,Gujarat       0   39         Single
# 1       148736    Hyderabad,Andhra Pradesh       0   52        Married
# 2        95965     Shimla,Himachal Pradesh       0   62        Married
# 3        61759                 Srinagar,JK       0   42         Single
# 4        49806              Imphal,Manipur       0   41         Single
# 5       139942                 Srinagar,JK       0   59         Single
# 6       131136              Aizawl,Mizoram       0   37         Single
# 7        87969             Kohima,Nagaland       1   63        Married
# 8       124554       Bhopal,Madhya Pradesh       0   59         Single
# 9        77997                 Srinagar,JK       1   55         Single
# 10       36272         Gandhinagar,Gujarat       0   47         Single
# 11      126015                 Patna,Bihar       0   68         Single
# ...

# %% [markdown]
# Create new variable as “No_of_30_plus_DPD = No_of_30_59_DPD+No_of_90_DPD+ No_of_60_89_DPD”,
# “No_of_60_plus_DPD = No_of_90_DPD+ No_of_60_89_DPD” in cust_data.

# %%
custdata['No_of_30_Plus_DPD'] = custdata['No_of_30_59_DPD']+custdata['No_of_60_89_DPD']+custdata['No_of_90_DPD']
custdata['No_of_60_Plus_DPD'] = custdata['No_of_60_89_DPD']+custdata['No_of_90_DPD']
custdata.head(2)
# Out:
#    ID  SeriousDlqin2yrs  RevolvingUtilization  No_of_30_59_DPD  DebtRatio  \
# 0   1                 1              0.766127                2   0.403261
# 1   2                 0              0.957151                0   0.796738
#
#    MonthlyIncome  No_Of_OpenCreditLines  No_of_90_DPD  No_of_RealEstateLoans  \
# 0           9120                     13             0                      6
# 1           2600                      4             0                      0
#
#    No_of_60_89_DPD  No_of_30_Plus_DPD  No_of_60_Plus_DPD
# 0                0                  2                  0
# 1                0                  0                  0

# %%
Perform below joins between cust_data & cust_demo.
a. Create data set “cust_leftjoin” using Left Join
b. Create data set “cust_rightjoin” using right Join
c. Create data set “cust_innterjoin” using inner Join
d. Create data set “cust_fulljoin” using full Join

# %%
cust_leftjoin=pd.merge(custdata,custdemo,how='left')
cust_rightjoin=pd.merge(custdata,custdemo,how='right')
cust_innerjoin=pd.merge(custdata,custdemo,how='inner')
cust_fulljoin=pd.merge(custdata,custdemo,how='outer')

# %% [markdown]
# Create two data sets by taking random sample from cust_demo with 5% data in first data set
# and 10000 observations in second data set.

# %%
custdemo.sample(frac=0.05, replace=True)
# Out:
#             ID                    Location  Gender  age Martial_Status  \
# 143740   88319        Dehradun,Uttarakhand       1   47        Married
# 6404     17285          Shillong,Meghalaya       1   85        Married
# 43714   118134                  Panjim,Goa       1   39        Married
# 57511    79191          Chandigarh,Haryana       1   37        Married
# 19751    43771          Chandigarh,Haryana       0   61        Married
# 57689    94235                 Srinagar,JK       1   67         Single
# 81621   133715          Chandigarh,Haryana       0   73         Single
# 4640     11091         Raipur,Chhattisgarh       0   60         Single
# 21481    15515         Bangalore,Karnataka       1   75         Single
# 34040     3684                 Patna,Bihar       1   47        Married
# 145811   19210                    Jammu,JK       0   49        Married
# 83167    41014                    Jammu,JK       0   52         Single
# ...

# %%
custdemo.sample(n=1000, replace=False)
# Out:
#             ID                    Location  Gender  age Martial_Status  \
# 49210    52870              Aizawl,Mizoram       0   27         Single
# 68397    90930              Imphal,Manipur       0   73        Married
# 52725    11354  Bhubaneswar,Odisha(Orissa)       0   63        Married
# 105871   91541    Hyderabad,Andhra Pradesh       1   55        Married
# 149068   23447          Mumbai,Maharashtra       1   52         Single
# 32851    60049  Itanagar,Arunachal Pradesh       1   69         Single
# 89472    43932  Itanagar,Arunachal Pradesh       0   73        Married
# 49897    90328         Bangalore,Karnataka       0   66        Married
# 35347    80059  Itanagar,Arunachal Pradesh       0   65        Married
# 3578     93383                Dispur,Assam       1   63         Single
# 36420    45563                  Panjim,Goa       1   44        Married
# 70883    36399         Bangalore,Karnataka       0   57         Single
# ...

# %%
Calculate “number of customers” and “number of married customer” 
using combined data set comes from left join of cust_data and cust_demo

# %%
cust_leftjoin.Martial_Status.where(cust_leftjoin.Martial_Status=='Married').value_counts()
# Out:
# Married    42821
# Name: Martial_Status, dtype: int64

# %% [markdown]
# 9. Create summary report with below column by combination of Gender, Serious_delinquency.
# a. Number of customers
# b. Percentage of customers
# c. Average Revolving utilization
# d. Standard deviation with in the utilization
# e. Average monthly income
# f. Maximum Monthly income
# g. Standard deviation with in the income
# h. Average Age
# i. Average Dependents

# %%
a=cust_innerjoin[['Gender','SeriousDlqin2yrs','ID']].groupby('Gender').count()
a
# Out:
#         SeriousDlqin2yrs     ID
# Gender
# 0                  93681  93681
# 1                  56198  56198

# %%
b=cust_innerjoin[['ID']].count()
b
# Out:
# ID    149879
# dtype: int64

# %%
c=a/b
c
# Out:
#               ID  SeriousDlqin2yrs
# Gender
# 0       0.625044               NaN
# 1       0.374956               NaN
