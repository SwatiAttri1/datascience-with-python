# %% [markdown]
# # Pandas - Filtering and Sorting Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo=pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", delimiter='\t')
chipo.head(4)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
#
#   choice_description item_price
# 0                NaN     $2.39
# 1       [Clementine]     $3.39
# 2            [Apple]     $3.39
# 3                NaN     $2.39

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo.item_price = [float(value[1 : -1]) for value in chipo.item_price]

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 180.6+ KB

# %%
#chipo[(chipo.item_price>=10)].count()
chipo.order_id.where(chipo.item_price>=10).count()
# Out:
# 1130

# %% [markdown]
# ### Step 5. What is the price of each item?
#     ###### print a data frame with only two columns item_name and item_price

# %%
chipo[['item_name','item_price']]
#chipo1
#chipo[['item_name','item_price']].groupby('item_name').sum().reset_index()
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# 5                              Chicken Bowl       10.98
# 6                             Side of Chips        1.69
# 7                             Steak Burrito       11.75
# 8                          Steak Soft Tacos        9.25
# 9                             Steak Burrito        9.25
# 10                      Chips and Guacamole        4.45
# 11                     Chicken Crispy Tacos        8.75
# 12                       Chicken Soft Tacos        8.75
# 13                             Chicken Bowl       11.25
# 14                      Chips and Guacamole        4.45
# 15    Chips and Tomatillo-Green Chili Salsa        2.39
# ...

# %%
### Step 6. Sort by the name of the item

# %%
chipo.sort_values(by='item_name', ascending=False)
#chipo[['item_name','item_price']].groupby('item_name').sum().reset_index().sort_values(by='item_name',ascending=True)
# Out:
#       order_id  quantity          item_name  \
# 3889      1559         2  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 738        304         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
# 2384       948         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 4573      1818         1  Veggie Salad Bowl
# 455        195         1  Veggie Salad Bowl
# 496        207         1  Veggie Salad Bowl
# 2156       869         1  Veggie Salad Bowl
# 2683      1066         1  Veggie Salad Bowl
# 3293      1321         1  Veggie Salad Bowl
# 295        128         1  Veggie Salad Bowl
# 4109      1646         1  Veggie Salad Bowl
# 2269       913         1  Veggie Salad Bowl
# 1316       536         1  Veggie Salad Bowl
# 2223       896         1  Veggie Salad Bowl
# 4541      1805         1  Veggie Salad Bowl
# 3223      1289         1  Veggie Salad Bowl
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.sort_values(by='item_price', ascending=False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %% [markdown]
# ### Step 8. How many times were a Veggie Salad Bowl ordered?

# %%
chipo.item_name.where(chipo.item_name=='Veggie Salad Bowl').value_counts()
# Out:
# Veggie Salad Bowl    18
# Name: item_name, dtype: int64

# %% [markdown]
# ### Step 9. How many times people orderd more than one Canned Soda?

# %%
chipo.item_name.where((chipo.quantity>=1) & (chipo.item_name=='Canned Soda')).value_counts()
# Out:
# Canned Soda    104
# Name: item_name, dtype: int64
