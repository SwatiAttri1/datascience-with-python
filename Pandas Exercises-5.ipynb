# %% [markdown]
# # Pandas Exercise: Apply function (Student Alcohol Consumption)

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Download the dataset from this [address](http://archive.ics.uci.edu/ml/datasets/STUDENT+ALCOHOL+CONSUMPTION).

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df=pd.read_csv("C:\Users\hp\Downloads\python\student-alcohol-consumption\student-por.csv")
df.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
df=df.iloc[:,:12]
df.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian
# 0  course   mother
# 1  course   father
# 2   other   mother
# 3    home   mother
# 4    home   father

# %% [markdown]
# ### Step 5. Create a lambda function that captalize strings.

# %%
df.applymap(lambda x:x.capitalize() if type(x)==str else x).head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     Gp   F   18       U     Gt3       A     4     4  At_home   Teacher
# 1     Gp   F   17       U     Gt3       T     1     1  At_home     Other
# 2     Gp   F   15       U     Le3       T     1     1  At_home     Other
# 3     Gp   F   15       U     Gt3       T     4     2   Health  Services
# 4     Gp   F   16       U     Gt3       T     3     3    Other     Other
#
#    reason guardian
# 0  Course   Mother
# 1  Course   Father
# 2   Other   Mother
# 3    Home   Mother
# 4    Home   Father

# %%
### Step 6. Capitalize both Mjob and Fjob

# %%
df['Mjob'] = df['Mjob'].apply(lambda x: x.capitalize())
df['Fjob'] = df['Fjob'].apply(lambda x: x.capitalize())
df[['Mjob','Fjob']].head(2)
# Out:
#       Mjob     Fjob
# 0  At_home  Teacher
# 1  At_home    Other

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
df.tail(1)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob   Fjob  \
# 648     MS   M   18       R     LE3       T     3     2  Services  Other
#
#      reason guardian
# 648  course   mother

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and captalize Mjob and Fjob.

# %%
#df['Mjob'] = df['Mjob'].apply(lambda x: x.capitalize())
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  At_home   Teacher
# 1     GP   F   17       U     GT3       T     1     1  At_home     Other
# 2     GP   F   15       U     LE3       T     1     1  At_home     Other
# 3     GP   F   15       U     GT3       T     4     2   Health  Services
# 4     GP   F   16       U     GT3       T     3     3    Other     Other
#
#    reason guardian
# 0  course   mother
# 1  course   father
# 2   other   mother
# 3    home   mother
# 4    home   father

# %% [markdown]
# ### Step 9. Create a function called majority that return a boolean value to a new column called legal_drinker

# %%
def majority(contact):
    if contact >= 18:
        return 'Legal'
    else:
        return 'Not Legal'

df['leagl_drinker'] = df['age'].apply(majority)
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.
# ##### I know this makes no sense, don't forget it is just an exercise

# %%
df[df.select_dtypes(include=['number']).columns] *= 10
df.head(4)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F  180       U     GT3       A    40    40  At_home   Teacher
# 1     GP   F  170       U     GT3       T    10    10  At_home     Other
# 2     GP   F  150       U     LE3       T    10    10  At_home     Other
# 3     GP   F  150       U     GT3       T    40    20   Health  Services
#
#    reason guardian
# 0  course   mother
# 1  course   father
# 2   other   mother
# 3    home   mother
